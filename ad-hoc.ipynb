# %%
import rawpy
import imageio

with rawpy.imread("input_photo/IMG_3207.CR3") as raw:
    mosaic = raw.raw_image.copy()   # Bayer mosaic

imageio.imwrite("input_photo/IMG_3207.tiff", mosaic.astype("uint16"))

# %%
import rawpy
import imageio
import numpy as np

with rawpy.imread("input_photo/IMG_3207.CR3") as raw:
    bayer = raw.raw_image.copy()  # Bayer mosaic
    pattern = raw.raw_pattern

imageio.imwrite("input_photo/IMG_3207b.png", bayer.astype(np.uint16))
print(pattern)
# Out:
# [[0 1]
#  [3 2]]
